# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('cancer patient data sets.csv')
df.head()
# Out:
#    index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0      0         P1   33       1              2            4             5
# 1      1        P10   17       1              3            1             5
# 2      2       P100   35       1              4            5             6
# 3      3      P1000   37       1              7            7             7
# 4      4       P101   46       1              6            8             7
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  ...  Fatigue  \
# 0                     4             3                     2  ...        3
# 1                     3             4                     2  ...        1
# 2                     5             5                     4  ...        8
# 3                     7             6                     7  ...        4
# 4                     7             7                     6  ...        3
#
# ...

# %%
df['Level'].unique()
# Out:
# array(['Low', 'Medium', 'High'], dtype=object)

# %%
print('Total columns: ',df.shape[1])
print('Dimensions: ', df.shape)
print('Size: ', df.size)
print('Memory usage: ', df.memory_usage())
print('First 50 records: ')
df.head(50)
print('Last 30 records: ')
df.tail(30)
# Out:
# Total columns:  26
# Dimensions:  (1000, 26)
# Size:  26000
# Memory usage:  Index                        132
# index                       8000
# Patient Id                  8000
# Age                         8000
# Gender                      8000
# Air Pollution               8000
# Alcohol use                 8000
# Dust Allergy                8000
# OccuPational Hazards        8000
# Genetic Risk                8000
# chronic Lung Disease        8000
# Balanced Diet               8000
# Obesity                     8000
# Smoking                     8000
# Passive Smoker              8000
# Chest Pain                  8000
# Coughing of Blood           8000
# Fatigue                     8000
# Weight Loss                 8000
# Shortness of Breath         8000
# Wheezing                    8000
# Swallowing Difficulty       8000
# Clubbing of Finger Nails    8000
# Frequent Cold               8000
# Dry Cough                   8000
# Snoring                     8000
# ...

# %%
print('Total number of samples: ', df.shape[0])
print('Total number of columns: ', df.shape[1])
# Out:
# Total number of samples:  1000
# Total number of columns:  26

# %%
df['Level'].value_counts()
# Out:
# Level
# High      365
# Medium    332
# Low       303
# Name: count, dtype: int64

# %%
sample = df.loc[550:900, 'Gender':'Coughing of Blood']
sample.to_csv('sample.csv')
sample.describe()
# Out:
#            Gender  Air Pollution  Alcohol use  Dust Allergy  \
# count  351.000000     351.000000   351.000000    351.000000
# mean     1.396011       3.988604     4.749288      5.319088
# std      0.489765       2.042376     2.622941      1.921504
# min      1.000000       1.000000     1.000000      1.000000
# 25%      1.000000       2.000000     2.000000      4.000000
# 50%      1.000000       4.000000     5.000000      6.000000
# 75%      2.000000       6.000000     7.000000      7.000000
# max      2.000000       8.000000     8.000000      8.000000
#
#        OccuPational Hazards  Genetic Risk  chronic Lung Disease  \
# count            351.000000    351.000000            351.000000
# mean               4.974359      4.726496              4.472934
# std                2.084480      2.112374              1.823257
# min                1.000000      1.000000              1.000000
# 25%                3.000000      3.000000              3.000000
# ...

# %%
print('index of Shortness of Breath: ', df.columns.get_loc('Shortness of Breath'))
print('index of Frequent Cold: ', df.columns.get_loc('Frequent Cold'))
sample2 = df.iloc[-20:, 18:23]
sample2.to_csv('sample2.csv')
sample2.describe()
# Out:
# index of Shortness of Breath:  18
# index of Frequent Cold:  22
#        Shortness of Breath   Wheezing  Swallowing Difficulty  \
# count            20.000000  20.000000               20.00000
# mean              5.400000   3.650000                3.95000
# std               2.542274   2.621269                2.37254
# min               2.000000   1.000000                1.00000
# 25%               3.750000   1.000000                1.75000
# 50%               5.000000   2.000000                4.00000
# 75%               7.500000   7.000000                6.00000
# max               9.000000   7.000000                8.00000
#
#        Clubbing of Finger Nails  Frequent Cold
# count                  20.00000      20.000000
# mean                    4.05000       4.650000
# std                     1.79106       1.496487
# min                     2.00000       2.000000
# 25%                     2.00000       4.000000
# 50%                     4.00000       4.000000
# ...

# %%
sample3 = df.iloc[[110,220,360,440,656,778,202,889]]
avg = sample3['Alcohol use'].mean()
print(avg)
# Out:
# 5.625

# %%
# continuation for Q3

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(numeric_only=True), annot=False, cmap="viridis")
plt.title("Correlation Heatmap")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=df['Age'], y=df['Frequent Cold'])
plt.title("Distribution of Age vs Frequent Cold")
plt.xlabel("Age")
plt.ylabel("Frequent Cold")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x=df['Obesity'],  patch_artist=True, boxprops=dict(facecolor='orange'))
plt.title("Outlier Detection in Obesity Feature")
plt.show()
